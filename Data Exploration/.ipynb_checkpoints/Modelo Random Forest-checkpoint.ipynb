# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

import pandas as pd
import numpy as np

# %%
results = pd.read_csv("../dataset/results.csv")
qualifying = pd.read_csv("../dataset/qualifying.csv")
qualifying_merged = pd.merge(results, qualifying, on=['raceId', 'driverId', 'constructorId'], how='inner')

# %%
def setStrip(n):
    if pd.isnull(n):
        return -1
    elif n < 3:
        return 1
    elif n < 6:
        return 2
    elif n < 9:
        return 3
    elif n < 12:
        return 4
    elif n < 15:
        return 5
    else: return 6

# %%
qualifying_merged['position_x'] = qualifying_merged['position_x'].map(setStrip)
qualifying_merged
# Out:
#       resultId  raceId  driverId  constructorId  number_x  grid  position_x  \
# 0            1      18         1              1      22.0     1           1
# 1            2      18         2              2       3.0     5           1
# 2            3      18         3              3       7.0     7           1
# 3            4      18         4              4       5.0    11           1
# 4            5      18         5              1      23.0     3           1
# 5            6      18         6              3       8.0    13           2
# 6            7      18         7              5      14.0    17           2
# 7            8      18         8              6       1.0    15           2
# 8            9      18         9              2       4.0     2           1
# 9           10      18        10              7      12.0    18           1
# 10          11      18        11              8      18.0    19           1
# 11          12      18        12              4       6.0    20           1
# 12          13      18        13              6       2.0     4           1
# 13          14      18        14              9       9.0     8           1
# 14          15      18        15              7      11.0     6           1
# 15          16      18        16             10      20.0    22           1
# 16          17      18        17              9      10.0    14           1
# 17          18      18        18             11      16.0    12           1
# 18          19      18        19              8      19.0    21           1
# 19          20      18        20              5      15.0     9           1
# 20          21      18        21             10      21.0    16           1
# 21          22      18        22             11      17.0    10           1
# 22          23      19         8              6       1.0     2           1
# 23          24      19         9              2       4.0     4           1
# 24          25      19         5              1      23.0     8           1
# 25          26      19        15              7      11.0     3           1
# 26          27      19         1              1      22.0     9           1
# 27          28      19         2              2       3.0     5           2
# 28          29      19        17              9      10.0     6           2
# 29          30      19         4              4       5.0     7           2
# ...        ...     ...       ...            ...       ...   ...         ...
# 7476     23752     987       832              4      55.0     8           2
# 7477     23753     987       842              5      10.0    19           2
# 7478     23754     987       828             15       9.0    17           2
# 7479     23755     987       836             15      94.0    15           2
# 7480     23756     987       154            210       8.0    11           3
# 7481     23757     987       840              3      18.0    16           3
# 7482     23758     987       843              5      28.0    18           1
# 7483     23759     987       839             10      31.0    10           1
# 7484     23760     987       838              1       2.0    12           1
# 7485     23761     987       825            210      20.0    13           1
# 7486     23762     988       822            131      77.0     1           1
# 7487     23763     988         1            131      44.0     2           1
# 7488     23764     988        20              6       5.0     3           1
# 7489     23765     988         8              6       7.0     5           1
# 7490     23766     988       830              9      33.0     6           1
# 7491     23767     988       807              4      27.0     7           2
# 7492     23768     988       815             10      11.0     8           2
# 7493     23769     988       839             10      31.0     9           2
# 7494     23770     988         4              1      14.0    11           2
# 7495     23771     988        13              3      19.0    10           2
# 7496     23772     988       154            210       8.0    16           2
# 7497     23773     988       838              1       2.0    13           2
# 7498     23774     988       825            210      20.0    14           2
# 7499     23775     988       836             15      94.0    18           2
# 7500     23776     988       843              5      28.0    20           3
# 7501     23777     988       842              5      10.0    17           3
# 7502     23778     988       828             15       9.0    19           3
# 7503     23779     988       840              3      18.0    15           3
# 7504     23780     988       832              4      55.0    12           1
# 7505     23781     988       817              9       3.0     4           1
#
#      positionText  positionOrder  points  ...  rank fastestLapTime  \
# 0               1              1    10.0  ...   2.0        01:27.5
# 1               2              2     8.0  ...   3.0        01:27.7
# 2               3              3     6.0  ...   5.0        01:28.1
# 3               4              4     5.0  ...   7.0        01:28.6
# 4               5              5     4.0  ...   1.0        01:27.4
# 5               6              6     3.0  ...  14.0        01:29.6
# 6               7              7     2.0  ...  12.0        01:29.5
# 7               8              8     1.0  ...   4.0        01:27.9
# 8               R              9     0.0  ...   9.0        01:28.8
# 9               R             10     0.0  ...  13.0        01:29.6
# 10              R             11     0.0  ...  15.0        01:30.9
# 11              R             12     0.0  ...  16.0        01:31.4
# 12              R             13     0.0  ...   6.0        01:28.2
# 13              R             14     0.0  ...  11.0        01:29.5
# 14              R             15     0.0  ...  10.0        01:29.3
# 15              R             16     0.0  ...  17.0        01:32.0
# 16              R             17     0.0  ...   NaN            NaN
# 17              R             18     0.0  ...   NaN            NaN
# 18              R             19     0.0  ...   NaN            NaN
# 19              R             20     0.0  ...   NaN            NaN
# 20              R             21     0.0  ...   NaN            NaN
# 21              D             22     0.0  ...   8.0        01:28.7
# 22              1              1    10.0  ...   2.0        01:35.4
# 23              2              2     8.0  ...   6.0        01:35.9
# 24              3              3     6.0  ...   7.0        01:35.9
# 25              4              4     5.0  ...   8.0        01:36.1
# 26              5              5     4.0  ...   3.0        01:35.5
# 27              6              6     3.0  ...   1.0        01:35.4
# 28              7              7     2.0  ...  12.0        01:36.7
# 29              8              8     1.0  ...  10.0        01:36.3
# ...           ...            ...     ...  ...   ...            ...
# 7476           11             11     0.0  ...  13.0        01:13.6
# 7477           12             12     0.0  ...   9.0        01:13.3
# 7478           13             13     0.0  ...  14.0        01:13.7
# 7479           14             14     0.0  ...  17.0        01:14.8
# 7480           15             15     0.0  ...  12.0        01:13.5
# 7481           16             16     0.0  ...   3.0        01:11.9
# 7482            R             17     0.0  ...  16.0        01:14.7
# 7483            R             18     0.0  ...   0.0            NaN
# 7484            R             19     0.0  ...   0.0            NaN
# 7485            R             20     0.0  ...   0.0            NaN
# 7486            1              1    25.0  ...   1.0        01:40.7
# 7487            2              2    18.0  ...   3.0        01:41.5
# 7488            3              3    15.0  ...   2.0        01:40.8
# 7489            4              4    12.0  ...   7.0        01:42.3
# 7490            5              5    10.0  ...   5.0        01:42.0
# 7491            6              6     8.0  ...   8.0        01:42.4
# 7492            7              7     6.0  ...  11.0        01:42.7
# 7493            8              8     4.0  ...  10.0        01:42.6
# 7494            9              9     2.0  ...   4.0        01:43.4
# 7495           10             10     1.0  ...  13.0        01:43.0
# 7496           11             11     0.0  ...   9.0        01:42.4
# 7497           12             12     0.0  ...  20.0        01:44.0
# 7498           13             13     0.0  ...  19.0        01:43.9
# 7499           14             14     0.0  ...  17.0        01:43.9
# 7500           15             15     0.0  ...  18.0        01:43.9
# 7501           16             16     0.0  ...  16.0        01:43.8
# 7502           17             17     0.0  ...  15.0        01:43.6
# 7503           18             18     0.0  ...   6.0        01:42.3
# 7504            R             19     0.0  ...  14.0        01:43.4
# 7505            R             20     0.0  ...  12.0        01:42.8
#
#       fastestLapSpeed  statusId  qualifyId number_y position_y        q1  \
# 0               218.3         1          1       22          1  1:26.572
# 1             217.586         1          5        3          5  1:25.960
# 2             216.719         1          7        7          7  1:26.295
# 3             215.464         1         12        5         12  1:26.907
# 4             218.385         1          3       23          3  1:25.664
# 5             212.974        11         14        8         14  1:26.891
# 6             213.224         5         18       14         18  1:27.446
# 7              217.18         5         16        1         16  1:26.140
# 8               215.1         4          2        4          2  1:26.103
# 9             213.166         3          9       12          9  1:26.919
# 10            210.038         7         20       18         20  1:28.208
# 11            208.907         8         21        6         21  1:28.330
# 12             216.51         5          4        2          4  1:25.994
# 13              213.3         4          8        9          8  1:26.381
# 14            213.758        10          6       11          6  1:26.427
# 15            207.461         9         19       20         19  1:27.859
# 16                NaN         4         15       10         15  1:26.914
# 17                NaN         4         13       16         13  1:26.712
# 18                NaN         4         22       19         22  1:29.059
# 19                NaN         4         10       15         10  1:26.702
# 20                NaN         4         17       21         17  1:27.207
# 21            215.141         2         11       17         11  1:26.369
# 22            209.158         1         24        1          2  1:35.645
# 23            208.033         1         28        4          6  1:35.794
# 24            208.031         1         25       23          3  1:35.227
# 25            207.715         1         27       11          5  1:35.205
# 26            209.033         1         26       22          4  1:35.392
# 27            209.244         1         29        3          7  1:35.729
# 28            206.366         1         30       10          8  1:35.440
# 29             207.24         1         31        5          9  1:35.983
# ...               ...       ...        ...      ...        ...       ...
# 7476          210.694        11       7507       55          9  1:10.227
# 7477          211.562        11       7515       10         17  1:10.686
# 7478          210.577        11       7517        9         19  1:10.875
# 7479          207.351        11       7514       94         16  1:10.678
# 7480          210.961        12       7510        8         12  1:10.148
# 7481          215.863        12       7516       18         18  1:10.776
# 7482          207.779         5       7513       28         15  1:10.625
# 7483              NaN         3       7509       31         11  1:10.168
# 7484              NaN         3       7511        2         13  1:10.286
# 7485              NaN         3       7512       20         14  1:10.521
# 7486          198.652         1       7520       77          1  1:37.356
# 7487          197.041         1       7521       44          2  1:37.391
# 7488          198.416         1       7522        5          3  1:37.817
# 7489          195.376         1       7524        7          5  1:37.453
# 7490          195.969         1       7525       33          6  1:38.021
# 7491          195.303         1       7526       27          7  1:38.781
# 7492          194.708         1       7527       11          8  1:38.601
# 7493          01:42.6         1       7528       31          9  1:38.896
# 7494           193.41        11       7530       14         11  1:38.820
# 7495          194.071        11       7529       19         10  1:38.629
# 7496          195.187        11       7535        8         16  1:39.516
# 7497          192.279        11       7532        2         13  1:38.777
# 7498          192.387        11       7533       20         14  1:39.395
# 7499            192.5        11       7537       94         18  1:39.930
# 7500          192.444        11       7539       28         20  1:40.471
# 7501          192.542        11       7536       10         17  1:39.724
# 7502          193.057        11       7538        9         19  1:39.994
# 7503          195.402        11       7534       18         15  1:39.503
# 7504           193.41        36       7531       55         12  1:38.810
# 7505          194.579         9       7523        3          4  1:38.016
#
#             q2        q3
# 0     1:25.187  1:26.714
# 1     1:25.518  1:27.236
# 2     1:26.059  1:28.687
# 3     1:26.188       NaN
# 4     1:25.452  1:27.079
# 5     1:26.413       NaN
# 6          NaN       NaN
# 7          NaN       NaN
# 8     1:25.315  1:26.869
# 9     1:26.164  1:29.593
# 10         NaN       NaN
# 11         NaN       NaN
# 12    1:25.691  1:27.178
# 13    1:26.063  1:29.041
# 14    1:26.101  1:28.527
# 15         NaN       NaN
# 16         NaN       NaN
# 17    1:26.259       NaN
# 18         NaN       NaN
# 19    1:25.842       NaN
# 20         NaN       NaN
# 21    1:26.173       NaN
# 22    1:34.188  1:36.230
# 23    1:34.811  1:36.727
# 24    1:34.759  1:36.613
# 25    1:34.960  1:36.711
# 26    1:34.627  1:36.709
# 27    1:34.648  1:36.753
# 28    1:34.967  1:37.009
# 29    1:35.140  1:38.450
# ...        ...       ...
# 7476  1:09.768  1:09.805
# 7477       NaN       NaN
# 7478       NaN       NaN
# 7479       NaN       NaN
# 7480  1:09.879       NaN
# 7481       NaN       NaN
# 7482       NaN       NaN
# 7483  1:09.830       NaN
# 7484  1:10.116       NaN
# 7485  1:10.154       NaN
# 7486  1:36.822  1:36.231
# 7487  1:36.742  1:36.403
# 7488  1:37.023  1:36.777
# 7489  1:37.302  1:36.985
# 7490  1:37.777  1:37.328
# 7491  1:38.138  1:38.282
# 7492  1:38.359  1:38.374
# 7493  1:38.392  1:38.397
# 7494  1:38.636       NaN
# 7495  1:38.565  1:38.550
# 7496       NaN       NaN
# 7497  1:38.808       NaN
# 7498  1:39.298       NaN
# 7499       NaN       NaN
# 7500       NaN       NaN
# 7501       NaN       NaN
# 7502       NaN       NaN
# 7503  1:39.646       NaN
# 7504  1:38.725       NaN
# 7505  1:37.583  1:36.959
#
# [7506 rows x 24 columns]

# %%
XTabl = qualifying_merged

XTabl = XTabl.drop('positionText', axis=1)
XTabl = XTabl.drop('resultId', axis=1)
XTabl = XTabl.drop('positionOrder', axis=1)
XTabl = XTabl.drop('time', axis=1)
XTabl = XTabl.drop('fastestLapTime', axis=1)
XTabl = XTabl.drop('q1', axis=1)
XTabl = XTabl.drop('q2', axis=1)
XTabl = XTabl.drop('q3', axis=1)
XTabl = XTabl.drop('milliseconds', axis=1)
#XTabl = XTabl.drop('grid', axis=1)
#XTabl = XTabl.drop('rank', axis=1)
XTabl = XTabl.drop('qualifyId', axis=1)
#XTabl = XTabl.drop('points', axis=1)
#XTabl = XTabl.drop('laps', axis=1)
XTabl = XTabl.drop('fastestLapSpeed', axis=1)
#XTabl = XTabl.drop('number_x', axis=1)
#XTabl = XTabl['points']

XTabl = XTabl.dropna()
YTabl = XTabl['position_x']
XTabl = XTabl.drop('position_x', axis=1)
XTabl
# Out:
#       raceId  driverId  constructorId  number_x  grid  laps  fastestLap  rank  \
# 0         18         1              1      22.0     1    58        39.0   2.0
# 1         18         2              2       3.0     5    58        41.0   3.0
# 2         18         3              3       7.0     7    58        41.0   5.0
# 3         18         4              4       5.0    11    58        58.0   7.0
# 4         18         5              1      23.0     3    58        43.0   1.0
# 5         18         6              3       8.0    13    57        50.0  14.0
# 6         18         7              5      14.0    17    55        22.0  12.0
# 7         18         8              6       1.0    15    53        20.0   4.0
# 8         18         9              2       4.0     2    47        15.0   9.0
# 9         18        10              7      12.0    18    43        23.0  13.0
# 10        18        11              8      18.0    19    32        24.0  15.0
# 11        18        12              4       6.0    20    30        20.0  16.0
# 12        18        13              6       2.0     4    29        23.0   6.0
# 13        18        14              9       9.0     8    25        21.0  11.0
# 14        18        15              7      11.0     6    19        18.0  10.0
# 15        18        16             10      20.0    22     8         8.0  17.0
# 21        18        22             11      17.0    10    58        44.0   8.0
# 22        19         8              6       1.0     2    56        37.0   2.0
# 23        19         9              2       4.0     4    56        39.0   6.0
# 24        19         5              1      23.0     8    56        19.0   7.0
# 25        19        15              7      11.0     3    56        53.0   8.0
# 26        19         1              1      22.0     9    56        53.0   3.0
# 27        19         2              2       3.0     5    56        55.0   1.0
# 28        19        17              9      10.0     6    56        53.0  12.0
# 29        19         4              4       5.0     7    56        40.0  10.0
# 30        19        14              9       9.0    12    56        55.0   9.0
# 31        19        18             11      16.0    11    56        56.0   4.0
# 32        19        12              4       6.0    13    56        52.0  15.0
# 33        19        21             10      21.0    17    55        52.0  16.0
# 34        19        22             11      17.0    14    55        55.0  11.0
# ...      ...       ...            ...       ...   ...   ...         ...   ...
# 7473     987         4              1      14.0     6    71        57.0  10.0
# 7474     987       815             10      11.0     5    71        61.0   8.0
# 7475     987       807              4      27.0     7    70        57.0  15.0
# 7476     987       832              4      55.0     8    70        67.0  13.0
# 7477     987       842              5      10.0    19    70        61.0   9.0
# 7478     987       828             15       9.0    17    70        70.0  14.0
# 7479     987       836             15      94.0    15    70        60.0  17.0
# 7480     987       154            210       8.0    11    69        66.0  12.0
# 7481     987       840              3      18.0    16    69        69.0   3.0
# 7482     987       843              5      28.0    18    40        29.0  16.0
# 7486     988       822            131      77.0     1    55        52.0   1.0
# 7487     988         1            131      44.0     2    55        51.0   3.0
# 7488     988        20              6       5.0     3    55         5.0   2.0
# 7489     988         8              6       7.0     5    55        53.0   7.0
# 7490     988       830              9      33.0     6    55        43.0   5.0
# 7491     988       807              4      27.0     7    55        53.0   8.0
# 7492     988       815             10      11.0     8    55        52.0  11.0
# 7493     988       839             10      31.0     9    55        47.0  10.0
# 7494     988         4              1      14.0    11    54        26.0   4.0
# 7495     988        13              3      19.0    10    54        45.0  13.0
# 7496     988       154            210       8.0    16    54        51.0   9.0
# 7497     988       838              1       2.0    13    54        50.0  20.0
# 7498     988       825            210      20.0    14    54        50.0  19.0
# 7499     988       836             15      94.0    18    54        50.0  17.0
# 7500     988       843              5      28.0    20    54        52.0  18.0
# 7501     988       842              5      10.0    17    54        33.0  16.0
# 7502     988       828             15       9.0    19    54        36.0  15.0
# 7503     988       840              3      18.0    15    54        52.0   6.0
# 7504     988       832              4      55.0    12    31        26.0  14.0
# 7505     988       817              9       3.0     4    20        13.0  12.0
#
#       statusId  number_y  position_y
# 0            1        22           1
# 1            1         3           5
# 2            1         7           7
# 3            1         5          12
# 4            1        23           3
# 5           11         8          14
# 6            5        14          18
# 7            5         1          16
# 8            4         4           2
# 9            3        12           9
# 10           7        18          20
# 11           8         6          21
# 12           5         2           4
# 13           4         9           8
# 14          10        11           6
# 15           9        20          19
# 21           2        17          11
# 22           1         1           2
# 23           1         4           6
# 24           1        23           3
# 25           1        11           5
# 26           1        22           4
# 27           1         3           7
# 28           1        10           8
# 29           1         5           9
# 30           1         9          12
# 31           1        16          11
# 32           1         6          13
# 33          11        21          17
# 34          11        17          14
# ...        ...       ...         ...
# 7473         1        14           7
# 7474         1        11           6
# 7475        11        27           8
# 7476        11        55           9
# 7477        11        10          17
# 7478        11         9          19
# 7479        11        94          16
# 7480        12         8          12
# 7481        12        18          18
# 7482         5        28          15
# 7486         1        77           1
# 7487         1        44           2
# 7488         1         5           3
# 7489         1         7           5
# 7490         1        33           6
# 7491         1        27           7
# 7492         1        11           8
# 7493         1        31           9
# 7494        11        14          11
# 7495        11        19          10
# 7496        11         8          16
# 7497        11         2          13
# 7498        11        20          14
# 7499        11        94          18
# 7500        11        28          20
# 7501        11        10          17
# 7502        11         9          19
# 7503        11        18          15
# 7504        36        55          12
# 7505         9         3           4
#
# [5356 rows x 11 columns]

# %%
qualifying_merged.groupby(['position_y'])['position_y'].count().sum()
# Out:
# 7506

# %%
x_raw_, y_raw = XTabl.values, YTabl.values

x_raw_ = x_raw_[:-1]
y_raw = y_raw[:-1]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_raw_, y_raw, test_size=0.2, random_state=42)

# %%
clf = RandomForestRegressor(100, min_samples_split=100)
clf.fit(X_train, Y_train)
Y_test_hat = clf.predict(X_test)
Y_train_hat = clf.predict(X_train)
Y_test_hat = np.rint(Y_test_hat)
Y_train_hat = np.rint(Y_train_hat)

# %%
metrics.accuracy_score(Y_test, Y_test_hat)
# Out:
# 0.7964519140989729

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Y_test_hat)
plt.plot(Y_test, alpha=0.5)

# %%
metrics.accuracy_score(Y_train, Y_train_hat)
# Out:
# 0.1842031029619182

# %%
plt.plot(Y_train[:100])
plt.plot(Y_train_hat[:100], alpha=0.5)
